# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='/home/aseem/deep-reinforcement-learning/p2-continuous-control/p2_continuous-control/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# The simulation contains `20` identical agents, each with its own copy of the environment.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.19649999560788273

# %% [markdown]
# When finished, you can close the environment.

# %%
import gym
import random
import torch
import time
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import random
  
import copy
from collections import namedtuple, deque

import Actor, Critic

import torch
import torch.nn.functional as F
import torch.optim as optim

BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 1024       # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 5e-4         # learning rate of the actor 
LR_CRITIC = 1e-3        # learning rate of the critic
WEIGHT_DECAY = 0.0000   # L2 weight decay

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Agent():
    """Interacts with and learns from the environment."""
    
    def __init__(self, state_size, action_size, random_seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            random_seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(random_seed)

        # Actor Network (w/ Target Network)
        self.actor_local = Actor(state_size, action_size, random_seed).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed).to(device)
        self.actor_optimizer = optim.Adam(self.actor_local.parameters(), lr=LR_ACTOR)

        # Critic Network (w/ Target Network)
        self.critic_local = Critic(state_size, action_size, random_seed).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed).to(device)
        self.critic_optimizer = optim.Adam(self.critic_local.parameters(), lr=LR_CRITIC, weight_decay=WEIGHT_DECAY)

        # Noise process
        self.noise = OUNoise(action_size, random_seed)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, random_seed)
    
    def step(self, state, action, reward, next_state, done, ts):
        
        """Save experience in replay memory, and use random sample from buffer to learn."""
        # Save experience / reward
        # self.memory.add(state, action, reward, next_state, done)
        for i in range(20):
            # print(states.shape[0], states.shape[1])
            self.memory.add(state[i], action[i], reward[i], next_state[i], done[i])
        
        # Learn, if enough samples are available in memory
        if ts%20 == 0:
            if len(self.memory) > BATCH_SIZE:
                for i in range(10):
                    experiences = self.memory.sample()
                    self.learn(experiences, GAMMA)

    def act(self, state, add_noise=True):
        """Returns actions for given state as per current policy."""
        
        state = torch.from_numpy(state).float().to(device)
        
        self.actor_local.eval()
        with torch.no_grad():
            action = self.actor_local(state).cpu().data.numpy()
        self.actor_local.train()
        
        if add_noise:
            for i in range(20):
                action[i] += self.noise.sample()
        return np.clip(action, -1, 1)


    def reset(self):
        self.noise.reset()

    def learn(self, experiences, gamma):
        """Update policy and value parameters using given batch of experience tuples.
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # ---------------------------- update critic ---------------------------- #
        # Get predicted next-state actions and Q values from target models
        actions_next = self.actor_target(next_states)
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_local(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # ---------------------------- update actor ---------------------------- #
        # Compute actor loss
        actions_pred = self.actor_local(states)
        actor_loss = -self.critic_local(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # ----------------------- update target networks ----------------------- #
        self.soft_update(self.critic_local, self.critic_target, TAU)
        self.soft_update(self.actor_local, self.actor_target, TAU)                     

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.15, sigma=0.2):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)

def ddpg(n_episodes=2000, max_t=1000):
        
    scores_deque = deque(maxlen=100)
    scores = []
    for i_episode in range(1, n_episodes+1):
        begin = time.time()
        avg_score = 0
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores_t = np.zeros(num_agents)                          # initialize the score (for each agent)
        agent.reset()
        score = 0
        for t_step in range(max_t):
            actions = agent.act(states)     
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished   
            agent.step(states, actions, rewards, next_states, dones, t_step)
            states = next_states
            scores_t += rewards
            if np.any(dones):
                break
        
        score = np.mean(scores_t)
        scores_deque.append(score)
        avg_score = np.mean(scores_deque)
        scores.append(score)        
        
        print("\nEpisode {:}\t Average Score {:.2f}\tMin Score {:.2f}\tMax Score {:.2f}".format(i_episode, avg_score, scores_t.min(), score_t.max()))
        print("Score: {:.2f}".format(score))

        end = time.time()
        diff = end - begin
        print("Time {:.2f} s\n".format(diff))

        if avg_score > 30:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')            
            break
    
    return scores

scores = ddpg()
# Out:
# Episode 1	 Average Score 0.48	Min Score 0.10	Max Score 1.22
# Score: 0.48
# Time 46.48 s
#
#
# Episode 2	 Average Score 0.58	Min Score 0.19	Max Score 1.65
# Score: 0.69
# Time 44.05 s
#
#
# Episode 3	 Average Score 0.68	Min Score 0.04	Max Score 1.90
# Score: 0.86
# Time 43.53 s
#
#
# Episode 4	 Average Score 0.69	Min Score 0.19	Max Score 1.61
# Score: 0.72
# Time 44.24 s
#
#
# Episode 5	 Average Score 0.75	Min Score 0.46	Max Score 2.34
# Score: 1.00
# Time 50.38 s
#
#
# Episode 6	 Average Score 0.80	Min Score 0.09	Max Score 2.06
# Score: 1.08
# Time 49.59 s
#
#
# Episode 7	 Average Score 0.89	Min Score 0.46	Max Score 3.03
# Score: 1.41
# Time 47.92 s
#
#
# Episode 8	 Average Score 0.93	Min Score 0.48	Max Score 2.47
# Score: 1.21
# Time 46.73 s
#
#
# Episode 9	 Average Score 0.99	Min Score 0.52	Max Score 3.28
# Score: 1.46
# Time 46.57 s
#
#
# Episode 10	 Average Score 1.04	Min Score 0.37	Max Score 2.83
# Score: 1.52
# Time 45.73 s
#
#
# Episode 11	 Average Score 1.07	Min Score 0.39	Max Score 2.84
# Score: 1.32
# Time 48.10 s
#
#
# Episode 12	 Average Score 1.11	Min Score 0.44	Max Score 3.77
# Score: 1.56
# Time 48.95 s
#
#
# Episode 13	 Average Score 1.16	Min Score 0.56	Max Score 4.14
# Score: 1.77
# Time 48.76 s
#
#
# Episode 14	 Average Score 1.21	Min Score 0.89	Max Score 4.08
# Score: 1.86
# Time 49.97 s
#
#
# Episode 15	 Average Score 1.25	Min Score 0.80	Max Score 3.96
# Score: 1.89
# Time 50.58 s
#
#
# Episode 16	 Average Score 1.30	Min Score 0.63	Max Score 4.31
# Score: 1.99
# Time 49.47 s
#
#
# Episode 17	 Average Score 1.34	Min Score 0.76	Max Score 3.56
# Score: 1.95
# Time 50.97 s
#
#
# Episode 18	 Average Score 1.38	Min Score 0.84	Max Score 3.34
# Score: 2.12
# Time 49.39 s
#
#
# Episode 19	 Average Score 1.42	Min Score 0.75	Max Score 4.29
# Score: 2.18
# Time 50.36 s
#
#
# Episode 20	 Average Score 1.50	Min Score 0.73	Max Score 6.89
# Score: 2.99
# Time 49.97 s
#
#
# Episode 21	 Average Score 1.56	Min Score 0.68	Max Score 4.77
# Score: 2.71
# Time 51.03 s
#
#
# Episode 22	 Average Score 1.63	Min Score 1.65	Max Score 6.55
# Score: 3.02
# Time 51.38 s
#
#
# Episode 23	 Average Score 1.68	Min Score 1.31	Max Score 5.84
# Score: 2.88
# Time 52.29 s
#
#
# Episode 24	 Average Score 1.73	Min Score 1.23	Max Score 5.75
# Score: 2.81
# Time 53.19 s
#
#
# Episode 25	 Average Score 1.76	Min Score 1.22	Max Score 3.93
# Score: 2.55
# Time 52.96 s
#
#
# Episode 26	 Average Score 1.81	Min Score 0.95	Max Score 5.72
# Score: 2.99
# Time 53.01 s
#
#
# Episode 27	 Average Score 1.88	Min Score 1.38	Max Score 7.13
# Score: 3.77
# Time 53.62 s
#
#
# Episode 28	 Average Score 1.93	Min Score 1.32	Max Score 5.45
# Score: 3.15
# Time 54.04 s
#
#
# Episode 29	 Average Score 1.99	Min Score 1.76	Max Score 6.08
# Score: 3.69
# Time 53.80 s
#
#
# Episode 30	 Average Score 2.07	Min Score 2.25	Max Score 7.58
# Score: 4.45
# Time 55.32 s
#
#
# Episode 31	 Average Score 2.12	Min Score 1.12	Max Score 7.87
# Score: 3.66
# Time 54.73 s
#
#
# Episode 32	 Average Score 2.19	Min Score 2.81	Max Score 6.19
# Score: 4.22
# Time 54.39 s
#
#
# Episode 33	 Average Score 2.26	Min Score 2.14	Max Score 9.13
# Score: 4.72
# Time 54.88 s
#
#
# Episode 34	 Average Score 2.33	Min Score 2.68	Max Score 6.73
# Score: 4.49
# Time 54.50 s
#
#
# Episode 35	 Average Score 2.42	Min Score 3.80	Max Score 7.40
# Score: 5.57
# Time 54.45 s
#
#
# Episode 36	 Average Score 2.51	Min Score 3.52	Max Score 8.86
# Score: 5.66
# Time 54.81 s
#
#
# Episode 37	 Average Score 2.60	Min Score 2.97	Max Score 8.23
# Score: 5.61
# Time 53.60 s
#
#
# Episode 38	 Average Score 2.69	Min Score 4.48	Max Score 8.00
# Score: 6.22
# Time 52.68 s
#
#
# Episode 39	 Average Score 2.77	Min Score 3.49	Max Score 10.57
# Score: 5.95
# Time 54.82 s
#
#
# Episode 40	 Average Score 2.86	Min Score 3.76	Max Score 9.29
# Score: 6.32
# Time 54.43 s
#
#
# Episode 41	 Average Score 2.94	Min Score 1.26	Max Score 9.23
# Score: 5.91
# Time 53.72 s
#
#
# Episode 42	 Average Score 3.02	Min Score 4.33	Max Score 9.55
# Score: 6.59
# Time 54.80 s
#
#
# Episode 43	 Average Score 3.11	Min Score 4.01	Max Score 10.34
# Score: 6.71
# Time 54.15 s
#
#
# Episode 44	 Average Score 3.21	Min Score 4.99	Max Score 12.49
# Score: 7.44
# Time 52.67 s
#
#
# Episode 45	 Average Score 3.29	Min Score 3.30	Max Score 11.51
# Score: 7.06
# Time 55.14 s
#
#
# Episode 46	 Average Score 3.39	Min Score 3.78	Max Score 11.18
# Score: 7.51
# Time 55.82 s
#
#
# Episode 47	 Average Score 3.52	Min Score 5.52	Max Score 13.60
# Score: 9.74
# Time 53.31 s
#
#
# Episode 48	 Average Score 3.62	Min Score 1.18	Max Score 11.92
# Score: 8.40
# Time 54.46 s
#
#
# Episode 49	 Average Score 3.73	Min Score 4.86	Max Score 13.09
# Score: 8.72
# Time 53.50 s
#
#
# Episode 50	 Average Score 3.84	Min Score 6.40	Max Score 15.54
# Score: 9.32
# Time 53.66 s
#
#
# Episode 51	 Average Score 3.96	Min Score 4.43	Max Score 17.41
# Score: 9.84
# Time 54.54 s
#
#
# Episode 52	 Average Score 4.04	Min Score 3.90	Max Score 11.45
# Score: 8.12
# Time 55.15 s
#
#
# Episode 53	 Average Score 4.15	Min Score 5.26	Max Score 20.75
# Score: 9.85
# Time 54.32 s
#
#
# Episode 54	 Average Score 4.25	Min Score 5.19	Max Score 17.62
# Score: 9.88
# Time 53.96 s
#
#
# Episode 55	 Average Score 4.34	Min Score 2.86	Max Score 12.99
# Score: 9.18
# Time 53.65 s
#
#
# Episode 56	 Average Score 4.44	Min Score 7.40	Max Score 12.91
# Score: 10.04
# Time 53.41 s
#
#
# Episode 57	 Average Score 4.57	Min Score 6.15	Max Score 16.55
# Score: 11.39
# Time 55.23 s
#
#
# Episode 58	 Average Score 4.67	Min Score 4.79	Max Score 13.94
# Score: 10.63
# Time 54.23 s
#
#
# Episode 59	 Average Score 4.80	Min Score 7.65	Max Score 17.21
# Score: 12.27
# Time 53.15 s
#
#
# Episode 60	 Average Score 4.93	Min Score 8.15	Max Score 18.48
# Score: 12.94
# Time 54.34 s
#
#
# Episode 61	 Average Score 5.07	Min Score 9.17	Max Score 18.25
# Score: 13.07
# Time 53.29 s
#
#
# Episode 62	 Average Score 5.19	Min Score 7.86	Max Score 17.66
# Score: 12.70
# Time 54.04 s
#
#
# Episode 63	 Average Score 5.33	Min Score 8.44	Max Score 23.72
# Score: 14.27
# Time 54.50 s
#
#
# Episode 64	 Average Score 5.48	Min Score 9.88	Max Score 22.73
# Score: 14.43
# Time 53.10 s
#
#
# Episode 65	 Average Score 5.63	Min Score 11.21	Max Score 20.23
# Score: 15.15
# Time 54.33 s
#
#
# Episode 66	 Average Score 5.78	Min Score 11.30	Max Score 22.59
# Score: 15.85
# Time 54.28 s
#
#
# Episode 67	 Average Score 5.91	Min Score 9.50	Max Score 19.03
# Score: 14.51
# Time 52.81 s
#
#
# Episode 68	 Average Score 6.04	Min Score 4.28	Max Score 24.71
# Score: 14.95
# Time 54.55 s
#
#
# Episode 69	 Average Score 6.19	Min Score 11.70	Max Score 23.56
# Score: 16.45
# Time 53.32 s
#
#
# Episode 70	 Average Score 6.34	Min Score 5.99	Max Score 25.69
# Score: 16.27
# Time 53.36 s
#
#
# Episode 71	 Average Score 6.50	Min Score 10.20	Max Score 28.81
# Score: 17.57
# Time 54.02 s
#
#
# Episode 72	 Average Score 6.65	Min Score 12.33	Max Score 29.56
# Score: 17.40
# Time 54.49 s
#
#
# Episode 73	 Average Score 6.76	Min Score 9.47	Max Score 19.37
# Score: 15.05
# Time 53.34 s
#
#
# Episode 74	 Average Score 6.88	Min Score 8.87	Max Score 19.07
# Score: 15.26
# Time 56.19 s
#
#
# Episode 75	 Average Score 7.00	Min Score 12.20	Max Score 20.11
# Score: 16.17
# Time 53.69 s
#
#
# Episode 76	 Average Score 7.11	Min Score 4.99	Max Score 26.55
# Score: 15.17
# Time 53.01 s
#
#
# Episode 77	 Average Score 7.19	Min Score 8.17	Max Score 27.02
# Score: 13.31
# Time 54.10 s
#
#
# Episode 78	 Average Score 7.30	Min Score 12.54	Max Score 20.58
# Score: 15.47
# Time 53.60 s
#
#
# Episode 79	 Average Score 7.39	Min Score 10.08	Max Score 17.11
# Score: 14.37
# Time 53.28 s
#
#
# Episode 80	 Average Score 7.47	Min Score 11.21	Max Score 19.78
# Score: 14.03
# Time 54.12 s
#
#
# Episode 81	 Average Score 7.55	Min Score 8.68	Max Score 19.38
# Score: 13.80
# Time 52.87 s
#
#
# Episode 82	 Average Score 7.63	Min Score 10.05	Max Score 18.39
# Score: 14.18
# Time 53.37 s
#
#
# Episode 83	 Average Score 7.71	Min Score 9.86	Max Score 20.78
# Score: 14.51
# Time 53.99 s
#
#
# Episode 84	 Average Score 7.79	Min Score 1.21	Max Score 22.25
# Score: 14.23
# Time 53.82 s
#
#
# Episode 85	 Average Score 7.86	Min Score 11.28	Max Score 17.22
# Score: 14.14
# Time 53.94 s
#
#
# Episode 86	 Average Score 7.95	Min Score 10.83	Max Score 23.49
# Score: 15.45
# Time 54.69 s
#
#
# Episode 87	 Average Score 8.03	Min Score 9.65	Max Score 24.43
# Score: 15.01
# Time 53.15 s
#
#
# Episode 88	 Average Score 8.11	Min Score 8.85	Max Score 24.14
# Score: 14.86
# Time 52.52 s
#
#
# Episode 89	 Average Score 8.18	Min Score 10.58	Max Score 21.93
# Score: 14.69
# Time 54.17 s
#
#
# Episode 90	 Average Score 8.27	Min Score 10.49	Max Score 25.25
# Score: 16.10
# Time 55.00 s
#
#
# Episode 91	 Average Score 8.33	Min Score 1.67	Max Score 18.17
# Score: 13.58
# Time 53.84 s
#
#
# Episode 92	 Average Score 8.39	Min Score 1.84	Max Score 27.65
# Score: 14.28
# Time 56.04 s
#
#
# Episode 93	 Average Score 8.45	Min Score 5.94	Max Score 25.17
# Score: 13.54
# Time 54.12 s
#
#
# Episode 94	 Average Score 8.53	Min Score 1.78	Max Score 21.52
# Score: 15.75
# Time 53.15 s
#
#
# Episode 95	 Average Score 8.63	Min Score 11.47	Max Score 26.30
# Score: 18.33
# Time 55.47 s
#
#
# Episode 96	 Average Score 8.73	Min Score 11.10	Max Score 23.19
# Score: 17.77
# Time 54.04 s
#
#
# Episode 97	 Average Score 8.81	Min Score 9.79	Max Score 21.23
# Score: 17.03
# Time 53.67 s
#
#
# Episode 98	 Average Score 8.88	Min Score 9.26	Max Score 22.81
# Score: 15.59
# Time 55.08 s
#
#
# Episode 99	 Average Score 8.94	Min Score 7.63	Max Score 25.87
# Score: 14.56
# Time 55.15 s
#
#
# Episode 100	 Average Score 8.97	Min Score 4.52	Max Score 22.19
# Score: 12.56
# Time 54.14 s
#
#
# Episode 101	 Average Score 9.09	Min Score 3.11	Max Score 30.67
# Score: 12.39
# Time 54.96 s
#
#
# Episode 102	 Average Score 9.21	Min Score 4.69	Max Score 34.62
# Score: 11.96
# Time 55.35 s
#
#
# Episode 103	 Average Score 9.31	Min Score 4.44	Max Score 18.36
# Score: 10.84
# Time 53.74 s
#
#
# Episode 104	 Average Score 9.41	Min Score 5.83	Max Score 15.95
# Score: 11.50
# Time 54.54 s
#
#
# Episode 105	 Average Score 9.52	Min Score 4.50	Max Score 34.55
# Score: 11.69
# Time 55.04 s
#
#
# Episode 106	 Average Score 9.63	Min Score 2.76	Max Score 20.52
# Score: 11.71
# Time 53.99 s
#
#
# Episode 107	 Average Score 9.73	Min Score 4.46	Max Score 19.93
# Score: 12.11
# Time 54.29 s
#
#
# Episode 108	 Average Score 9.84	Min Score 4.18	Max Score 16.39
# Score: 11.65
# Time 53.80 s
#
#
# Episode 109	 Average Score 9.95	Min Score 2.44	Max Score 17.64
# Score: 12.48
# Time 54.05 s
#
#
# Episode 110	 Average Score 10.06	Min Score 6.16	Max Score 22.41
# Score: 12.91
# Time 55.80 s
#
#
# Episode 111	 Average Score 10.17	Min Score 3.98	Max Score 17.93
# Score: 12.44
# Time 54.97 s
#
#
# Episode 112	 Average Score 10.31	Min Score 6.18	Max Score 25.93
# Score: 15.50
# Time 54.99 s
#
#
# Episode 113	 Average Score 10.43	Min Score 6.59	Max Score 21.38
# Score: 13.49
# Time 55.48 s
#
#
# Episode 114	 Average Score 10.56	Min Score 5.46	Max Score 35.39
# Score: 14.74
# Time 54.52 s
#
#
# Episode 115	 Average Score 10.68	Min Score 3.43	Max Score 34.20
# Score: 13.91
# Time 53.23 s
#
#
# Episode 116	 Average Score 10.80	Min Score 6.20	Max Score 23.89
# Score: 14.02
# Time 54.26 s
#
#
# Episode 117	 Average Score 10.91	Min Score 4.50	Max Score 24.59
# Score: 13.25
# Time 53.65 s
#
#
# Episode 118	 Average Score 11.04	Min Score 3.88	Max Score 24.39
# Score: 14.41
# Time 53.57 s
#
#
# Episode 119	 Average Score 11.13	Min Score 4.77	Max Score 20.44
# Score: 12.06
# Time 54.87 s
#
#
# Episode 120	 Average Score 11.24	Min Score 3.63	Max Score 24.55
# Score: 13.40
# Time 54.39 s
#
#
# Episode 121	 Average Score 11.37	Min Score 2.99	Max Score 26.90
# Score: 15.59
# Time 53.22 s
#
#
# Episode 122	 Average Score 11.48	Min Score 7.98	Max Score 20.57
# Score: 14.14
# Time 53.96 s
#
#
# Episode 123	 Average Score 11.64	Min Score 3.58	Max Score 28.50
# Score: 19.35
# Time 54.14 s
#
#
# Episode 124	 Average Score 11.80	Min Score 12.14	Max Score 27.54
# Score: 19.00
# Time 53.79 s
#
#
# Episode 125	 Average Score 11.99	Min Score 4.41	Max Score 29.48
# Score: 21.32
# Time 54.25 s
#
#
# Episode 126	 Average Score 12.16	Min Score 9.69	Max Score 29.87
# Score: 19.65
# Time 53.70 s
#
#
# Episode 127	 Average Score 12.33	Min Score 15.21	Max Score 27.03
# Score: 20.41
# Time 55.68 s
#
#
# Episode 128	 Average Score 12.55	Min Score 21.36	Max Score 29.67
# Score: 25.17
# Time 58.24 s
#
#
# Episode 129	 Average Score 12.74	Min Score 18.89	Max Score 28.94
# Score: 23.39
# Time 55.65 s
#
#
# Episode 130	 Average Score 12.95	Min Score 19.28	Max Score 33.75
# Score: 24.94
# Time 53.20 s
#
#
# Episode 131	 Average Score 13.15	Min Score 14.31	Max Score 37.29
# Score: 23.54
# Time 54.90 s
#
#
# Episode 132	 Average Score 13.29	Min Score 10.53	Max Score 26.89
# Score: 18.49
# Time 55.70 s
#
#
# Episode 133	 Average Score 13.42	Min Score 13.36	Max Score 23.96
# Score: 17.93
# Time 54.72 s
#
#
# Episode 134	 Average Score 13.58	Min Score 16.06	Max Score 27.24
# Score: 20.69
# Time 55.13 s
#
#
# Episode 135	 Average Score 13.75	Min Score 15.65	Max Score 34.09
# Score: 21.97
# Time 53.98 s
#
#
# Episode 136	 Average Score 13.89	Min Score 14.60	Max Score 30.78
# Score: 20.19
# Time 52.34 s
#
#
# Episode 137	 Average Score 14.03	Min Score 16.18	Max Score 24.73
# Score: 19.67
# Time 53.35 s
#
#
# Episode 138	 Average Score 14.19	Min Score 17.12	Max Score 30.32
# Score: 22.24
# Time 53.61 s
#
#
# Episode 139	 Average Score 14.34	Min Score 16.00	Max Score 30.12
# Score: 20.80
# Time 54.13 s
#
#
# Episode 140	 Average Score 14.49	Min Score 14.69	Max Score 33.84
# Score: 21.44
# Time 56.53 s
#
#
# Episode 141	 Average Score 14.63	Min Score 13.85	Max Score 26.29
# Score: 19.70
# Time 57.55 s
#
#
# Episode 142	 Average Score 14.79	Min Score 15.98	Max Score 29.65
# Score: 22.95
# Time 55.71 s
#
#
# Episode 143	 Average Score 14.94	Min Score 14.43	Max Score 28.34
# Score: 21.41
# Time 54.91 s
#
#
# Episode 144	 Average Score 15.11	Min Score 17.90	Max Score 31.84
# Score: 23.82
# Time 54.45 s
#
#
# Episode 145	 Average Score 15.28	Min Score 17.70	Max Score 34.92
# Score: 24.75
# Time 54.06 s
#
#
# Episode 146	 Average Score 15.45	Min Score 19.32	Max Score 31.95
# Score: 24.52
# Time 54.13 s
#
#
# Episode 147	 Average Score 15.60	Min Score 17.66	Max Score 30.70
# Score: 24.39
# Time 53.97 s
#
#
# Episode 148	 Average Score 15.76	Min Score 19.62	Max Score 33.33
# Score: 24.49
# Time 52.63 s
#
#
# Episode 149	 Average Score 15.95	Min Score 21.58	Max Score 33.51
# Score: 28.16
# Time 53.26 s
#
#
# Episode 150	 Average Score 16.12	Min Score 17.88	Max Score 36.00
# Score: 26.37
# Time 54.09 s
#
#
# Episode 151	 Average Score 16.27	Min Score 16.93	Max Score 30.74
# Score: 24.29
# Time 53.03 s
#
#
# Episode 152	 Average Score 16.42	Min Score 18.35	Max Score 30.40
# Score: 23.62
# Time 54.76 s
#
#
# Episode 153	 Average Score 16.58	Min Score 19.50	Max Score 33.45
# Score: 25.21
# Time 53.25 s
#
#
# Episode 154	 Average Score 16.74	Min Score 20.27	Max Score 34.01
# Score: 25.89
# Time 53.42 s
#
#
# Episode 155	 Average Score 16.90	Min Score 21.15	Max Score 31.04
# Score: 25.27
# Time 55.07 s
#
#
# Episode 156	 Average Score 17.07	Min Score 19.76	Max Score 33.18
# Score: 27.28
# Time 52.93 s
#
#
# Episode 157	 Average Score 17.19	Min Score 17.79	Max Score 30.26
# Score: 23.75
# Time 53.72 s
#
#
# Episode 158	 Average Score 17.33	Min Score 16.53	Max Score 29.50
# Score: 23.79
# Time 53.80 s
#
#
# Episode 159	 Average Score 17.46	Min Score 21.61	Max Score 30.12
# Score: 25.37
# Time 54.84 s
#
#
# Episode 160	 Average Score 17.56	Min Score 17.73	Max Score 29.67
# Score: 23.21
# Time 54.17 s
#
#
# Episode 161	 Average Score 17.68	Min Score 18.20	Max Score 28.51
# Score: 24.95
# Time 54.71 s
#
#
# Episode 162	 Average Score 17.81	Min Score 20.26	Max Score 31.14
# Score: 25.60
# Time 52.51 s
#
#
# Episode 163	 Average Score 17.94	Min Score 15.76	Max Score 35.78
# Score: 26.98
# Time 54.48 s
#
#
# Episode 164	 Average Score 18.06	Min Score 17.65	Max Score 41.70
# Score: 26.68
# Time 53.46 s
#
#
# Episode 165	 Average Score 18.19	Min Score 21.71	Max Score 33.47
# Score: 28.30
# Time 55.05 s
#
#
# Episode 166	 Average Score 18.27	Min Score 14.81	Max Score 30.49
# Score: 23.89
# Time 55.53 s
#
#
# Episode 167	 Average Score 18.39	Min Score 18.01	Max Score 39.91
# Score: 26.59
# Time 55.54 s
#
#
# Episode 168	 Average Score 18.52	Min Score 18.15	Max Score 36.15
# Score: 27.56
# Time 53.81 s
#
#
# Episode 169	 Average Score 18.60	Min Score 15.67	Max Score 34.59
# Score: 25.27
# Time 54.16 s
#
#
# Episode 170	 Average Score 18.67	Min Score 7.51	Max Score 30.99
# Score: 22.57
# Time 55.10 s
#
#
# Episode 171	 Average Score 18.75	Min Score 18.55	Max Score 32.78
# Score: 26.00
# Time 55.67 s
#
#
# Episode 172	 Average Score 18.83	Min Score 18.71	Max Score 31.92
# Score: 25.28
# Time 55.74 s
#
#
# Episode 173	 Average Score 18.92	Min Score 18.81	Max Score 30.13
# Score: 24.27
# Time 55.33 s
#
#
# Episode 174	 Average Score 19.02	Min Score 17.38	Max Score 38.13
# Score: 24.80
# Time 58.59 s
#
#
# Episode 175	 Average Score 19.09	Min Score 18.93	Max Score 29.28
# Score: 23.84
# Time 57.66 s
#
#
# Episode 176	 Average Score 19.18	Min Score 17.69	Max Score 28.18
# Score: 23.82
# Time 58.55 s
#
#
# Episode 177	 Average Score 19.26	Min Score 15.61	Max Score 29.62
# Score: 21.17
# Time 58.49 s
#
#
# Episode 178	 Average Score 19.36	Min Score 19.23	Max Score 32.77
# Score: 25.12
# Time 53.99 s
#
#
# Episode 179	 Average Score 19.46	Min Score 18.25	Max Score 28.96
# Score: 24.44
# Time 54.21 s
#
#
# Episode 180	 Average Score 19.55	Min Score 15.73	Max Score 35.90
# Score: 23.55
# Time 54.74 s
#
#
# Episode 181	 Average Score 19.68	Min Score 22.38	Max Score 35.43
# Score: 26.47
# Time 53.61 s
#
#
# Episode 182	 Average Score 19.80	Min Score 16.67	Max Score 34.14
# Score: 25.90
# Time 53.40 s
#
#
# Episode 183	 Average Score 19.93	Min Score 23.04	Max Score 32.40
# Score: 27.38
# Time 53.86 s
#
#
# Episode 184	 Average Score 20.06	Min Score 20.89	Max Score 32.19
# Score: 27.41
# Time 58.86 s
#
#
# Episode 185	 Average Score 20.21	Min Score 19.35	Max Score 33.54
# Score: 28.99
# Time 61.91 s
#
#
# Episode 186	 Average Score 20.33	Min Score 19.02	Max Score 33.87
# Score: 27.51
# Time 55.87 s
#
#
# Episode 187	 Average Score 20.44	Min Score 22.30	Max Score 30.58
# Score: 26.10
# Time 56.37 s
#
#
# Episode 188	 Average Score 20.56	Min Score 22.86	Max Score 31.50
# Score: 27.17
# Time 54.96 s
#
#
# Episode 189	 Average Score 20.69	Min Score 21.45	Max Score 34.90
# Score: 27.74
# Time 54.94 s
#
#
# Episode 190	 Average Score 20.82	Min Score 11.05	Max Score 36.34
# Score: 28.83
# Time 57.68 s
#
#
# Episode 191	 Average Score 20.98	Min Score 22.06	Max Score 42.32
# Score: 29.75
# Time 56.06 s
#
#
# Episode 192	 Average Score 21.14	Min Score 21.02	Max Score 41.37
# Score: 30.42
# Time 55.43 s
#
#
# Episode 193	 Average Score 21.30	Min Score 22.07	Max Score 36.32
# Score: 29.91
# Time 55.93 s
#
#
# Episode 194	 Average Score 21.42	Min Score 19.94	Max Score 33.56
# Score: 27.41
# Time 55.88 s
#
#
# Episode 195	 Average Score 21.53	Min Score 19.72	Max Score 40.68
# Score: 29.27
# Time 54.13 s
#
#
# Episode 196	 Average Score 21.63	Min Score 20.65	Max Score 41.28
# Score: 27.95
# Time 54.95 s
#
#
# Episode 197	 Average Score 21.72	Min Score 20.42	Max Score 32.36
# Score: 26.18
# Time 53.10 s
#
#
# Episode 198	 Average Score 21.80	Min Score 17.52	Max Score 38.19
# Score: 23.63
# Time 53.42 s
#
#
# Episode 199	 Average Score 21.95	Min Score 20.71	Max Score 35.66
# Score: 29.05
# Time 52.76 s
#
#
# Episode 200	 Average Score 22.10	Min Score 18.45	Max Score 37.05
# Score: 27.84
# Time 51.75 s
#
#
# Episode 201	 Average Score 22.28	Min Score 23.19	Max Score 36.09
# Score: 29.64
# Time 52.68 s
#
#
# Episode 202	 Average Score 22.41	Min Score 17.82	Max Score 34.37
# Score: 25.47
# Time 53.55 s
#
#
# Episode 203	 Average Score 22.56	Min Score 9.26	Max Score 34.50
# Score: 25.37
# Time 53.62 s
#
#
# Episode 204	 Average Score 22.71	Min Score 20.73	Max Score 33.83
# Score: 27.44
# Time 53.06 s
#
#
# Episode 205	 Average Score 22.87	Min Score 20.86	Max Score 32.70
# Score: 27.01
# Time 54.05 s
#
#
# Episode 206	 Average Score 23.03	Min Score 19.45	Max Score 39.75
# Score: 27.94
# Time 54.04 s
#
#
# Episode 207	 Average Score 23.19	Min Score 22.08	Max Score 35.68
# Score: 28.50
# Time 54.40 s
#
#
# Episode 208	 Average Score 23.32	Min Score 18.96	Max Score 31.56
# Score: 24.44
# Time 55.63 s
#
#
# Episode 209	 Average Score 23.46	Min Score 19.18	Max Score 36.10
# Score: 26.09
# Time 53.77 s
#
#
# Episode 210	 Average Score 23.60	Min Score 20.93	Max Score 35.17
# Score: 27.49
# Time 54.65 s
#
#
# Episode 211	 Average Score 23.74	Min Score 22.47	Max Score 37.64
# Score: 26.39
# Time 54.63 s
#
#
# Episode 212	 Average Score 23.86	Min Score 18.64	Max Score 39.80
# Score: 26.64
# Time 56.79 s
#
#
# Episode 213	 Average Score 23.94	Min Score 14.16	Max Score 30.54
# Score: 22.23
# Time 55.10 s
#
#
# Episode 214	 Average Score 24.06	Min Score 19.46	Max Score 33.97
# Score: 26.49
# Time 54.01 s
#
#
# Episode 215	 Average Score 24.17	Min Score 19.15	Max Score 31.50
# Score: 24.61
# Time 57.83 s
#
#
# Episode 216	 Average Score 24.30	Min Score 20.03	Max Score 31.81
# Score: 27.12
# Time 54.77 s
#
#
# Episode 217	 Average Score 24.46	Min Score 24.63	Max Score 36.99
# Score: 29.65
# Time 53.41 s
#
#
# Episode 218	 Average Score 24.60	Min Score 21.51	Max Score 32.14
# Score: 28.34
# Time 54.63 s
#
#
# Episode 219	 Average Score 24.74	Min Score 18.36	Max Score 31.77
# Score: 25.82
# Time 55.40 s
#
#
# Episode 220	 Average Score 24.89	Min Score 21.42	Max Score 33.42
# Score: 28.06
# Time 53.38 s
#
#
# Episode 221	 Average Score 25.01	Min Score 18.80	Max Score 40.41
# Score: 28.07
# Time 53.34 s
#
#
# Episode 222	 Average Score 25.12	Min Score 7.68	Max Score 32.14
# Score: 25.51
# Time 54.31 s
#
#
# Episode 223	 Average Score 25.21	Min Score 23.58	Max Score 37.51
# Score: 28.07
# Time 53.82 s
#
#
# Episode 224	 Average Score 25.28	Min Score 19.95	Max Score 33.46
# Score: 26.02
# Time 55.97 s
#
#
# Episode 225	 Average Score 25.31	Min Score 18.24	Max Score 32.29
# Score: 24.36
# Time 54.77 s
#
#
# Episode 226	 Average Score 25.36	Min Score 15.21	Max Score 28.78
# Score: 23.96
# Time 52.81 s
#
#
# Episode 227	 Average Score 25.39	Min Score 16.82	Max Score 31.43
# Score: 24.29
# Time 54.44 s
#
#
# Episode 228	 Average Score 25.40	Min Score 19.74	Max Score 38.12
# Score: 25.59
# Time 56.17 s
#
#
# Episode 229	 Average Score 25.39	Min Score 14.65	Max Score 29.17
# Score: 22.14
# Time 56.45 s
#
#
# Episode 230	 Average Score 25.36	Min Score 18.33	Max Score 30.24
# Score: 22.61
# Time 55.69 s
#
#
# Episode 231	 Average Score 25.40	Min Score 22.05	Max Score 30.89
# Score: 27.12
# Time 55.92 s
#
#
# Episode 232	 Average Score 25.50	Min Score 23.36	Max Score 37.76
# Score: 28.81
# Time 54.32 s
#
#
# Episode 233	 Average Score 25.59	Min Score 20.62	Max Score 31.83
# Score: 26.53
# Time 55.49 s
#
#
# Episode 234	 Average Score 25.64	Min Score 21.48	Max Score 34.08
# Score: 25.83
# Time 54.34 s
#
#
# Episode 235	 Average Score 25.67	Min Score 14.08	Max Score 29.13
# Score: 25.42
# Time 53.69 s
#
#
# Episode 236	 Average Score 25.78	Min Score 27.75	Max Score 40.09
# Score: 31.34
# Time 55.35 s
#
#
# Episode 237	 Average Score 25.86	Min Score 22.29	Max Score 32.90
# Score: 27.47
# Time 55.04 s
#
#
# Episode 238	 Average Score 25.92	Min Score 19.80	Max Score 32.32
# Score: 27.87
# Time 52.39 s
#
#
# Episode 239	 Average Score 26.01	Min Score 22.23	Max Score 39.02
# Score: 30.24
# Time 54.04 s
#
#
# Episode 240	 Average Score 26.08	Min Score 23.81	Max Score 35.83
# Score: 28.58
# Time 53.85 s
#
#
# Episode 241	 Average Score 26.19	Min Score 19.55	Max Score 38.07
# Score: 30.40
# Time 53.22 s
#
#
# Episode 242	 Average Score 26.25	Min Score 15.69	Max Score 41.75
# Score: 29.04
# Time 55.70 s
#
#
# Episode 243	 Average Score 26.32	Min Score 19.96	Max Score 36.73
# Score: 28.08
# Time 54.05 s
#
#
# Episode 244	 Average Score 26.37	Min Score 21.62	Max Score 36.17
# Score: 28.94
# Time 51.99 s
#
#
# Episode 245	 Average Score 26.40	Min Score 21.98	Max Score 35.62
# Score: 27.57
# Time 55.25 s
#
#
# Episode 246	 Average Score 26.42	Min Score 18.94	Max Score 37.15
# Score: 26.61
# Time 55.84 s
#
#
# Episode 247	 Average Score 26.45	Min Score 21.38	Max Score 35.50
# Score: 27.38
# Time 53.05 s
#
#
# Episode 248	 Average Score 26.47	Min Score 19.20	Max Score 33.33
# Score: 26.91
# Time 53.99 s
#
#
# Episode 249	 Average Score 26.46	Min Score 18.67	Max Score 37.18
# Score: 27.24
# Time 53.89 s
#
#
# Episode 250	 Average Score 26.48	Min Score 18.28	Max Score 35.35
# Score: 28.12
# Time 53.67 s
#
#
# Episode 251	 Average Score 26.52	Min Score 19.97	Max Score 34.08
# Score: 27.65
# Time 54.73 s
#
#
# Episode 252	 Average Score 26.58	Min Score 16.16	Max Score 36.84
# Score: 29.89
# Time 54.27 s
#
#
# Episode 253	 Average Score 26.61	Min Score 22.05	Max Score 33.93
# Score: 28.34
# Time 53.79 s
#
#
# Episode 254	 Average Score 26.65	Min Score 25.98	Max Score 34.73
# Score: 29.72
# Time 52.89 s
#
#
# Episode 255	 Average Score 26.71	Min Score 23.70	Max Score 38.77
# Score: 31.90
# Time 51.65 s
#
#
# Episode 256	 Average Score 26.76	Min Score 24.70	Max Score 39.34
# Score: 31.81
# Time 58.93 s
#
#
# Episode 257	 Average Score 26.83	Min Score 26.40	Max Score 37.31
# Score: 30.78
# Time 55.71 s
#
#
# Episode 258	 Average Score 26.91	Min Score 23.74	Max Score 37.67
# Score: 31.29
# Time 54.01 s
#
#
# Episode 259	 Average Score 26.97	Min Score 23.81	Max Score 35.87
# Score: 32.25
# Time 52.96 s
#
#
# Episode 260	 Average Score 27.06	Min Score 27.17	Max Score 35.25
# Score: 31.89
# Time 54.80 s
#
#
# Episode 261	 Average Score 27.11	Min Score 26.73	Max Score 33.90
# Score: 30.16
# Time 53.79 s
#
#
# Episode 262	 Average Score 27.18	Min Score 26.46	Max Score 38.43
# Score: 32.80
# Time 53.66 s
#
#
# Episode 263	 Average Score 27.24	Min Score 28.71	Max Score 36.64
# Score: 32.86
# Time 53.82 s
#
#
# Episode 264	 Average Score 27.30	Min Score 22.48	Max Score 42.50
# Score: 32.66
# Time 53.75 s
#
#
# Episode 265	 Average Score 27.35	Min Score 26.30	Max Score 42.11
# Score: 33.29
# Time 56.30 s
#
#
# Episode 266	 Average Score 27.45	Min Score 25.91	Max Score 37.20
# Score: 33.15
# Time 53.52 s
#
#
# Episode 267	 Average Score 27.51	Min Score 24.28	Max Score 37.62
# Score: 33.08
# Time 52.68 s
#
#
# Episode 268	 Average Score 27.57	Min Score 27.81	Max Score 39.14
# Score: 33.73
# Time 53.67 s
#
#
# Episode 269	 Average Score 27.65	Min Score 27.36	Max Score 38.96
# Score: 33.34
# Time 53.58 s
#
#
# Episode 270	 Average Score 27.77	Min Score 29.48	Max Score 39.20
# Score: 34.48
# Time 52.86 s
#
#
# Episode 271	 Average Score 27.87	Min Score 29.61	Max Score 39.98
# Score: 35.37
# Time 55.36 s
#
#
# Episode 272	 Average Score 27.97	Min Score 31.09	Max Score 41.76
# Score: 35.35
# Time 53.32 s
#
#
# Episode 273	 Average Score 28.04	Min Score 24.37	Max Score 43.34
# Score: 32.02
# Time 53.87 s
#
#
# Episode 274	 Average Score 28.12	Min Score 26.41	Max Score 40.17
# Score: 32.51
# Time 53.53 s
#
#
# Episode 275	 Average Score 28.23	Min Score 24.36	Max Score 41.37
# Score: 34.44
# Time 53.26 s
#
#
# Episode 276	 Average Score 28.34	Min Score 31.49	Max Score 40.45
# Score: 35.41
# Time 53.44 s
#
#
# Episode 277	 Average Score 28.48	Min Score 27.29	Max Score 40.91
# Score: 34.36
# Time 52.78 s
#
#
# Episode 278	 Average Score 28.57	Min Score 28.73	Max Score 40.84
# Score: 34.96
# Time 53.27 s
#
#
# Episode 279	 Average Score 28.65	Min Score 28.03	Max Score 34.79
# Score: 31.83
# Time 53.97 s
#
#
# Episode 280	 Average Score 28.73	Min Score 27.65	Max Score 43.47
# Score: 32.05
# Time 52.93 s
#
#
# Episode 281	 Average Score 28.79	Min Score 28.21	Max Score 37.58
# Score: 32.21
# Time 53.95 s
#
#
# Episode 282	 Average Score 28.86	Min Score 29.08	Max Score 38.03
# Score: 33.27
# Time 53.78 s
#
#
# Episode 283	 Average Score 28.92	Min Score 27.02	Max Score 42.23
# Score: 32.67
# Time 52.31 s
#
#
# Episode 284	 Average Score 28.97	Min Score 27.80	Max Score 37.52
# Score: 32.97
# Time 54.42 s
#
#
# Episode 285	 Average Score 29.02	Min Score 28.59	Max Score 43.63
# Score: 33.80
# Time 53.20 s
#
#
# Episode 286	 Average Score 29.06	Min Score 26.17	Max Score 37.34
# Score: 31.49
# Time 52.95 s
#
#
# Episode 287	 Average Score 29.12	Min Score 28.72	Max Score 42.96
# Score: 32.40
# Time 54.39 s
#
#
# Episode 288	 Average Score 29.18	Min Score 29.01	Max Score 36.26
# Score: 33.06
# Time 54.13 s
#
#
# Episode 289	 Average Score 29.22	Min Score 25.92	Max Score 35.64
# Score: 31.49
# Time 52.66 s
#
#
# Episode 290	 Average Score 29.24	Min Score 26.02	Max Score 33.92
# Score: 30.82
# Time 54.12 s
#
#
# Episode 291	 Average Score 29.27	Min Score 29.45	Max Score 37.45
# Score: 32.74
# Time 52.67 s
#
#
# Episode 292	 Average Score 29.29	Min Score 27.73	Max Score 36.28
# Score: 32.56
# Time 53.45 s
#
#
# Episode 293	 Average Score 29.32	Min Score 27.83	Max Score 37.16
# Score: 33.21
# Time 54.85 s
#
#
# Episode 294	 Average Score 29.38	Min Score 27.29	Max Score 39.33
# Score: 32.58
# Time 51.88 s
#
#
# Episode 295	 Average Score 29.42	Min Score 29.02	Max Score 37.60
# Score: 33.74
# Time 53.21 s
#
#
# Episode 296	 Average Score 29.45	Min Score 25.79	Max Score 36.64
# Score: 30.96
# Time 53.92 s
#
#
# Episode 297	 Average Score 29.54	Min Score 27.06	Max Score 41.89
# Score: 34.83
# Time 52.84 s
#
#
# Episode 298	 Average Score 29.62	Min Score 27.82	Max Score 36.99
# Score: 32.41
# Time 53.85 s
#
#
# Episode 299	 Average Score 29.66	Min Score 24.06	Max Score 36.47
# Score: 32.47
# Time 53.77 s
#
#
# Episode 300	 Average Score 29.70	Min Score 26.51	Max Score 34.96
# Score: 31.54
# Time 53.42 s
#
#
# Episode 301	 Average Score 29.73	Min Score 20.05	Max Score 39.09
# Score: 32.97
# Time 53.53 s
#
#
# Episode 302	 Average Score 29.80	Min Score 19.66	Max Score 38.03
# Score: 32.52
# Time 53.26 s
#
#
# Episode 303	 Average Score 29.86	Min Score 23.38	Max Score 36.74
# Score: 31.91
# Time 52.67 s
#
#
# Episode 304	 Average Score 29.92	Min Score 29.76	Max Score 37.31
# Score: 33.10
# Time 53.51 s
#
#
# Episode 305	 Average Score 29.97	Min Score 23.39	Max Score 39.72
# Score: 31.82
# Time 52.79 s
#
#
# Episode 306	 Average Score 29.99	Min Score 25.38	Max Score 33.90
# Score: 30.33
# Time 52.58 s
#
#
# Episode 307	 Average Score 30.01	Min Score 26.45	Max Score 40.32
# Score: 30.48
# Time 53.40 s

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')

plt.show()
